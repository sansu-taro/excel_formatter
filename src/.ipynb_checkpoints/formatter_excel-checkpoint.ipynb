# %% [raw]
# import openpyxl
# import pandas as pd
# import numpy as np
#
# def find_borders(sheet):
#     borders = {'left': [], 'right': [], 'top': [], 'bottom': []}
#     for row in sheet.iter_rows():
#         for cell in row:
#             if cell.border:
#                 border_styles = {
#                     'left': cell.border.left.style if cell.border.left else None,
#                     'right': cell.border.right.style if cell.border.right else None,
#                     'top': cell.border.top.style if cell.border.top else None,
#                     'bottom': cell.border.bottom.style if cell.border.bottom else None
#                 }
#                 for side, style in border_styles.items():
#                     if style:
#                         borders[side].append((cell.row, cell.column))
#     return borders
#
# def find_bordered_ranges(borders):
#     ranges = []
#     for top in borders['top']:
#         for bottom in borders['bottom']:
#             if top[1] == bottom[1]:  # 同じ列
#                 for left in borders['left']:
#                     for right in borders['right']:
#                         if left[0] == right[0]:  # 同じ行
#                             if top[0] <= bottom[0] and left[1] <= right[1]:  # 有効な範囲
#                                 ranges.append((top[0], left[1], bottom[0], right[1]))
#     return ranges
#
# def extract_dataframes(sheet, ranges):
#     dataframes = []
#     for start_row, start_col, end_row, end_col in ranges:
#         data = []
#         for row in sheet.iter_rows(min_row=start_row, max_row=end_row, min_col=start_col, max_col=end_col, values_only=True):
#             data.append(list(row))
#         df = pd.DataFrame(data)
#         df_title = df.iloc[0, 1] if len(df.columns) > 1 else None  # タイトルは左上のセルの隣のセルにあると仮定
#         df_number = df.iloc[0, 0]  # 番号は左上のセルにあると仮定
#         try:
#             df_number = float(df_number)  # 数値に変換可能なら変換
#         except (ValueError, TypeError):
#             df_number = float('inf')  # 変換できない場合は非常に大きな値を割り当てる
#         dataframes.append({'number': df_number, 'title': df_title, 'data': df})
#     return dataframes
#
# def sort_and_save_dataframes(file_path, sheet_name, dataframes):
#     dataframes = sorted(dataframes, key=lambda x: x['number'])
#
#     # 新しいワークブックとシートを作成
#     new_workbook = openpyxl.Workbook()
#     new_sheet = new_workbook.active
#     new_sheet.title = sheet_name
#
#     current_row = 1
#     for df_dict in dataframes:
#         number = df_dict['number']
#         title = df_dict['title']
#         df = df_dict['data']
#
#         # 番号とタイトルを書き込む
#         new_sheet.cell(row=current_row, column=1, value=number)
#         new_sheet.cell(row=current_row, column=2, value=title)
#
#         # データフレームを書き込む
#         for r_idx, row in enumerate(df.values):
#             for c_idx, value in enumerate(row):
#                 new_sheet.cell(row=current_row + r_idx + 1, column=c_idx + 1, value=value)
#
#         # 現在の行を更新（1行空白をあける）
#         current_row += len(df) + 2
#
#     # ワークブックを保存
#     sorted_file_path = 'sorted_' + file_path.split('/')[-1]
#     new_workbook.save(sorted_file_path)
#     return sorted_file_path
#
# # 使用例
# file_path = 'input_files/sample.xlsx'  # ファイルパスを置き換えてください
# sheet_name = 'シート1'  # シート名を置き換えてください
#
# # ワークブックとシートを読み込む
# workbook = openpyxl.load_workbook(file_path)
# sheet = workbook[sheet_name]
#
# # 1. シートから黒い線が引かれた位置を特定
# borders = find_borders(sheet)
#
# # 2. 黒い線で囲まれた領域を特定
# ranges = find_bordered_ranges(borders)
#
# # 3. 囲まれた領域をデータフレームとして抽出
# dataframes = extract_dataframes(sheet, ranges)
#
# # 4. データフレームをソートして保存
# sorted_file_path = sort_and_save_dataframes(file_path, sheet_name, dataframes)
# print(f"ソートされたファイルが {sorted_file_path} として保存されました。")
# input_files/sample.xlsx

# %%
from math import sqrt

import openpyxl
import pandas as pd
from openpyxl.styles import Border, Side
from openpyxl.utils import column_index_from_string, get_column_letter

# エクセルファイルを開く
file_path = 'input_files/sample.xlsx'
wb = openpyxl.load_workbook(file_path)
sheet = wb.active

# 黒い枠線の定義
black_color = 'FF000000'

# 1. topとleftに線が引かれているセルの位置を特定しリストに格納します
top_left_cells = []
for row in sheet.iter_rows():
    for cell in row:
        if (cell.border.top and cell.border.top.color and cell.border.top.color.rgb == black_color and
            cell.border.left and cell.border.left.color and cell.border.left.color.rgb == black_color and
            (not cell.border.bottom or not cell.border.bottom.color or cell.border.bottom.color.rgb != black_color) and
            (not cell.border.right or not cell.border.right.color or cell.border.right.color.rgb != black_color)):
            top_left_cells.append(cell.coordinate)

# 2. bottomとrightだけに線が引かれているセルの位置を特定します
bottom_right_cells = []
for row in sheet.iter_rows():
    for cell in row:
        if (cell.border.bottom and cell.border.bottom.color and cell.border.bottom.color.rgb == black_color and
            cell.border.right and cell.border.right.color and cell.border.right.color.rgb == black_color and
            (not cell.border.top or not cell.border.top.color or cell.border.top.color.rgb != black_color) and
            (not cell.border.left or not cell.border.left.color or cell.border.left.color.rgb != black_color)):
            bottom_right_cells.append(cell.coordinate)

# 3. 1と2で特定したリストの中から最も直線距離が少ないセルの組み合わせを囲まれた領域とみなします
def calculate_distance(cell1, cell2):
    col1, row1 = ''.join([i for i in cell1 if i.isalpha()]), ''.join([i for i in cell1 if i.isdigit()])
    col2, row2 = ''.join([i for i in cell2 if i.isalpha()]), ''.join([i for i in cell2 if i.isdigit()])
    col1_idx, row1_idx = column_index_from_string(col1), int(row1)
    col2_idx, row2_idx = column_index_from_string(col2), int(row2)
    return sqrt((col1_idx - col2_idx)**2 + (row1_idx - row2_idx)**2)

# 各範囲をデータフレームとして読み込む
dataframes = []
for top_left in top_left_cells:
    min_distance = float('inf')
    closest_bottom_right = None
    print(top_left)
    for bottom_right in bottom_right_cells:
        distance = calculate_distance(top_left, bottom_right)
        if distance < min_distance:
            min_distance = distance
            closest_bottom_right = bottom_right
    
    if closest_bottom_right:
        start_col_letter, start_row = ''.join([i for i in top_left if i.isalpha()]), ''.join([i for i in top_left if i.isdigit()])
        end_col_letter, end_row = ''.join([i for i in closest_bottom_right if i.isalpha()]), ''.join([i for i in closest_bottom_right if i.isdigit()])
        start_col = column_index_from_string(start_col_letter)
        end_col = column_index_from_string(end_col_letter)
        usecols = f"{get_column_letter(start_col)}:{get_column_letter(end_col)}"
        nrows = int(end_row) - int(start_row) + 1
        skiprows = int(start_row) - 1

        print(f"Reading range: usecols={usecols}, nrows={nrows}, skiprows={skiprows}")  # デバッグ用出力

        if nrows > 0:
            df = pd.read_excel(file_path, sheet_name=sheet.title, usecols=usecols, nrows=nrows, skiprows=skiprows)
            dataframes.append(df)

# 読み込んだデータフレームを表示
for i, df in enumerate(dataframes):
    print(f"DataFrame {i+1}:")
    print(df)
    print("\n")
# Out:
# Reading range: usecols=B:F, nrows=9, skiprows=2
# Reading range: usecols=H:F, nrows=9, skiprows=2
# Reading range: usecols=A:F, nrows=-2, skiprows=13
# Reading range: usecols=G:F, nrows=-2, skiprows=13
# Reading range: usecols=K:L, nrows=-2, skiprows=13
# DataFrame 1:
#   Unnamed: 1   量  割合  合計  hoge
# 0         素材 NaN NaN NaN   NaN
# 1         素材 NaN NaN NaN   NaN
# 2         素材 NaN NaN NaN   NaN
# 3         素材 NaN NaN NaN   NaN
# 4         素材 NaN NaN NaN   NaN
# 5         素材 NaN NaN NaN   NaN
# 6         素材 NaN NaN NaN   NaN
# 7         素材 NaN NaN NaN   NaN
#
#
# DataFrame 2:
# Empty DataFrame
# Columns: []
# Index: []

# %%
top_left_cells
# Out:
# ['B3', 'H3', 'A14', 'G14', 'K14']
